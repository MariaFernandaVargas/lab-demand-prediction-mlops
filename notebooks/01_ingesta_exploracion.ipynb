# %%
# 01_ingesta_exploracion.ipynb

# 📦 Librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📥 Cargar los datos
df = pd.read_csv('../data/ventas_simuladas.csv', parse_dates=['fecha'])

# 👀 Vista rápida
print("Dimensiones del dataset:", df.shape)
print("\nPrimeras filas:")
display(df.head())

# ℹ️ Información general
print("\nTipos de datos:")
print(df.dtypes)

# 🧹 Valores nulos
print("\nValores nulos por columna:")
print(df.isnull().sum())

# 📊 Estadísticas generales
print("\nEstadísticas descriptivas:")
display(df.describe())

# 📆 Agregación por fecha
demanda_por_fecha = df.groupby('fecha')['demanda'].sum().reset_index()

# 📈 Visualización de la demanda total en el tiempo
plt.figure(figsize=(14, 5))
sns.lineplot(data=demanda_por_fecha, x='fecha', y='demanda')
plt.title("Demanda total diaria")
plt.xlabel("Fecha")
plt.ylabel("Demanda")
plt.grid(True)
plt.show()

# 📊 Distribución de demanda por producto
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='producto', y='demanda')
plt.title("Distribución de demanda por producto")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# Dimensiones del dataset: (1365, 4)
#
# Primeras filas:
#        fecha    restaurante     producto  demanda
# 0 2024-01-01  Restaurante A  Hamburguesa       66
# 1 2024-01-01  Restaurante A        Pizza       58
# 2 2024-01-01  Restaurante A     Ensalada       31
# 3 2024-01-01  Restaurante A        Tacos       86
# 4 2024-01-01  Restaurante A        Sushi       28
# Tipos de datos:
# fecha          datetime64[ns]
# restaurante            object
# producto               object
# demanda                 int64
# dtype: object
#
# Valores nulos por columna:
# fecha          0
# restaurante    0
# producto       0
# demanda        0
# dtype: int64
#
# Estadísticas descriptivas:
#                      fecha      demanda
# count                 1365  1365.000000
# mean   2024-02-15 00:00:00    58.854945
# min    2024-01-01 00:00:00    12.000000
# 25%    2024-01-23 00:00:00    39.000000
# 50%    2024-02-15 00:00:00    58.000000
# 75%    2024-03-09 00:00:00    78.000000
# ...
